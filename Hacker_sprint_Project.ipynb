# %%
import csv

# %%
file_path = r"C:\Users\niles\Downloads\organizations-1000 (1).csv"

# %%
with open(file_path,"r") as csv_file:   #to open and close
    csv_reader = csv.reader(csv_file)
    data =[]                 # store before delete
    for row in csv_reader:
        data.append(row)   #

# %%
len(data)   #length of the dataset
# Out:
# 1001

# %%
data[:10000]
# Out:
# [['Index',
#   'Organization Id',
#   'Name',
#   'Website',
#   'Country',
#   'Description',
#   'Founded',
#   'Industry',
#   'Number of employees'],
#  ['1',
#   'E84A904909dF528',
#   'Liu-Hoover',
#   'http://www.day-hartman.org/',
#   'Western Sahara',
#   'Ergonomic zero administration knowledge user',
#   '1980',
#   'Online Publishing',
#   '6852'],
#  ['2',
#   'AAC4f9aBF86EAeF',
#   'Orr-Armstrong',
#   'https://www.chapman.net/',
#   'Algeria',
#   'Ergonomic radical budgetary management',
#   '1970',
#   'Import / Export',
#   '7994'],
#  ['3',
#   'ad2eb3C8C24DB87',
#   'Gill-Lamb',
#   'http://lin.com/',
#   "Cote d'Ivoire",
#   'Programmable intermediate conglomeration',
#   '2005',
#   'Apparel / Fashion',
#   '5105'],
#  ['4',
#   'D76BB12E5eE165B',
#   'Bauer-Weiss',
#   'https://gillespie-stout.com/',
#   'United States of America',
#   'Synergistic maximized definition',
#   '2015',
#   'Dairy',
#   '9069'],
#  ['5',
#   '2F31EddF2Db9aAE',
#   'Love-Palmer',
# ...

# %%
print(data)
# Out:
# [['Index', 'Organization Id', 'Name', 'Website', 'Country', 'Description', 'Founded', 'Industry', 'Number of employees'], ['1', 'E84A904909dF528', 'Liu-Hoover', 'http://www.day-hartman.org/', 'Western Sahara', 'Ergonomic zero administration knowledge user', '1980', 'Online Publishing', '6852'], ['2', 'AAC4f9aBF86EAeF', 'Orr-Armstrong', 'https://www.chapman.net/', 'Algeria', 'Ergonomic radical budgetary management', '1970', 'Import / Export', '7994'], ['3', 'ad2eb3C8C24DB87', 'Gill-Lamb', 'http://lin.com/', "Cote d'Ivoire", 'Programmable intermediate conglomeration', '2005', 'Apparel / Fashion', '5105'], ['4', 'D76BB12E5eE165B', 'Bauer-Weiss', 'https://gillespie-stout.com/', 'United States of America', 'Synergistic maximized definition', '2015', 'Dairy', '9069'], ['5', '2F31EddF2Db9aAE', 'Love-Palmer', 'https://kramer.com/', 'Denmark', 'Optimized optimizing moderator', '2010', 'Management Consulting', '6991'], ['6', '6774DC1dB00BD11', 'Farmer, Edwards and Andrade', 'http://wolfe-boyd.
# ...

# %%
# List of columns
header = data[0]
print(header)
# Out:
# ['Index', 'Organization Id', 'Name', 'Website', 'Country', 'Description', 'Founded', 'Industry', 'Number of employees']

# %%
row_data = data[1:]   #keeping first row
print(row_data)
# Out:
# [['1', 'E84A904909dF528', 'Liu-Hoover', 'http://www.day-hartman.org/', 'Western Sahara', 'Ergonomic zero administration knowledge user', '1980', 'Online Publishing', '6852'], ['2', 'AAC4f9aBF86EAeF', 'Orr-Armstrong', 'https://www.chapman.net/', 'Algeria', 'Ergonomic radical budgetary management', '1970', 'Import / Export', '7994'], ['3', 'ad2eb3C8C24DB87', 'Gill-Lamb', 'http://lin.com/', "Cote d'Ivoire", 'Programmable intermediate conglomeration', '2005', 'Apparel / Fashion', '5105'], ['4', 'D76BB12E5eE165B', 'Bauer-Weiss', 'https://gillespie-stout.com/', 'United States of America', 'Synergistic maximized definition', '2015', 'Dairy', '9069'], ['5', '2F31EddF2Db9aAE', 'Love-Palmer', 'https://kramer.com/', 'Denmark', 'Optimized optimizing moderator', '2010', 'Management Consulting', '6991'], ['6', '6774DC1dB00BD11', 'Farmer, Edwards and Andrade', 'http://wolfe-boyd.com/', 'Norfolk Island', 'Virtual leadingedge benchmark', '2003', 'Mental Health Care', '3503'], ['7', '116B5cD4eE1fAAc',
# ...

# %%
# first five rows
row_data[:5]
# Out:
# [['1',
#   'E84A904909dF528',
#   'Liu-Hoover',
#   'http://www.day-hartman.org/',
#   'Western Sahara',
#   'Ergonomic zero administration knowledge user',
#   '1980',
#   'Online Publishing',
#   '6852'],
#  ['2',
#   'AAC4f9aBF86EAeF',
#   'Orr-Armstrong',
#   'https://www.chapman.net/',
#   'Algeria',
#   'Ergonomic radical budgetary management',
#   '1970',
#   'Import / Export',
#   '7994'],
#  ['3',
#   'ad2eb3C8C24DB87',
#   'Gill-Lamb',
#   'http://lin.com/',
#   "Cote d'Ivoire",
#   'Programmable intermediate conglomeration',
#   '2005',
#   'Apparel / Fashion',
#   '5105'],
#  ['4',
#   'D76BB12E5eE165B',
#   'Bauer-Weiss',
#   'https://gillespie-stout.com/',
#   'United States of America',
#   'Synergistic maximized definition',
#   '2015',
#   'Dairy',
#   '9069'],
#  ['5',
#   '2F31EddF2Db9aAE',
#   'Love-Palmer',
#   'https://kramer.com/',
#   'Denmark',
#   'Optimized optimizing moderator',
#   '2010',
#   'Management Consulting',
#   '6991']]

# %%
#last 5 row
row_data[-5 :: -1]
# Out:
# [['996',
#   'e5CEc38aa9A580b',
#   'Bullock Group',
#   'https://medina-bernard.com/',
#   'Turkmenistan',
#   'Public-key scalable conglomeration',
#   '1998',
#   'Wine / Spirits',
#   '6547'],
#  ['995',
#   '27CEbbbBCF4E17f',
#   'Curtis LLC',
#   'http://www.davenport.com/',
#   'Finland',
#   'Upgradable demand-driven success',
#   '1975',
#   'Philanthropy',
#   '36'],
#  ['994',
#   '6fcB10dA7E6f9Df',
#   'Hood Ltd',
#   'http://www.berry.com/',
#   "Cote d'Ivoire",
#   'Customer-focused 4thgeneration Graphical User Interface',
#   '1972',
#   'Machinery',
#   '640'],
#  ['993',
#   '35762be17cA3D47',
#   'Howe and Sons',
#   'https://www.nunez.com/',
#   'Cocos (Keeling) Islands',
#   'Future-proofed didactic middleware',
#   '2007',
#   'Logistics / Procurement',
#   '1424'],
#  ['992',
#   '958CAbB9B17124D',
#   'Vega, Miller and Calderon',
#   'http://www.joseph-contreras.com/',
#   'Cambodia',
#   'Sharable asymmetric monitoring',
#   '2012',
# ...

# %%
# find the organization founded before 2000 --d

# %%
for org in row_data[1:3]:
    if int(org[6]) <= 2000:
        print(org)
# Out:
# ['2', 'AAC4f9aBF86EAeF', 'Orr-Armstrong', 'https://www.chapman.net/', 'Algeria', 'Ergonomic radical budgetary management', '1970', 'Import / Export', '7994']

# %%
for org in row_data:
    if int(org[6]) <= 2000:
        print(org)
# Out:
# ['1', 'E84A904909dF528', 'Liu-Hoover', 'http://www.day-hartman.org/', 'Western Sahara', 'Ergonomic zero administration knowledge user', '1980', 'Online Publishing', '6852']
# ['2', 'AAC4f9aBF86EAeF', 'Orr-Armstrong', 'https://www.chapman.net/', 'Algeria', 'Ergonomic radical budgetary management', '1970', 'Import / Export', '7994']
# ['7', '116B5cD4eE1fAAc', 'Bass, Hester and Mcclain', 'https://meza-smith.com/', 'Uzbekistan', 'Multi-tiered system-worthy hub', '1994', 'Computer Hardware', '2762']
# ['8', 'AB2eA15d98b6BD4', 'Strickland, Gray and Jensen', 'http://kerr.info/', 'Israel', 'Team-oriented fresh-thinking knowledge user', '1987', 'Performing Arts', '7020']
# ['9', '0c6D831e8DceCfE', 'Sparks, Decker and Powell', 'https://www.howe.net/', 'Israel', 'Down-sized content-based info-mediaries', '1977', 'Marketing / Advertising / Sales', '2709']
# ...

# %%
org_2000 = [org for org in row_data if int(org[6]) < 2000]
print(org_2000)
# Out:
# [['1', 'E84A904909dF528', 'Liu-Hoover', 'http://www.day-hartman.org/', 'Western Sahara', 'Ergonomic zero administration knowledge user', '1980', 'Online Publishing', '6852'], ['2', 'AAC4f9aBF86EAeF', 'Orr-Armstrong', 'https://www.chapman.net/', 'Algeria', 'Ergonomic radical budgetary management', '1970', 'Import / Export', '7994'], ['7', '116B5cD4eE1fAAc', 'Bass, Hester and Mcclain', 'https://meza-smith.com/', 'Uzbekistan', 'Multi-tiered system-worthy hub', '1994', 'Computer Hardware', '2762'], ['8', 'AB2eA15d98b6BD4', 'Strickland, Gray and Jensen', 'http://kerr.info/', 'Israel', 'Team-oriented fresh-thinking knowledge user', '1987', 'Performing Arts', '7020'], ['9', '0c6D831e8DceCfE', 'Sparks, Decker and Powell', 'https://www.howe.net/', 'Israel', 'Down-sized content-based info-mediaries', '1977', 'Marketing / Advertising / Sales', '2709'], ['10', '9ABE0c8aee135d6', 'Osborn, Ford and Macdonald', 'http://www.mcdonald-watts.biz/', 'Syrian Arab Republic', 'Optional coherent focus group
# ...

# %%
for org in row_data:
    
    print(org[6])
# Out:
# 1980
# 1970
# 2005
# 2015
# 2010
# 2003
# 1994
# 1987
# 1977
# 1990
# 2019
# 2019
# 1990
# 1972
# 1997
# 2012
# 2014
# 1994
# 1973
# 1988
# 1972
# 1978
# 2005
# 2011
# 2013
# 1988
# 1980
# 2016
# 2016
# 1972
# 1972
# 2002
# 2019
# 1977
# 1972
# 1999
# 1983
# 1997
# 1975
# 2004
# 2015
# 1996
# 1976
# 2011
# 1997
# 1988
# 2010
# 2003
# 2020
# 1986
# 1995
# 2014
# 1986
# 2004
# 1977
# 1982
# 2016
# 1988
# 2020
# 2004
# 2014
# 2000
# 2020
# 2006
# 2008
# 1977
# 2018
# 1994
# 2018
# 1986
# 1970
# 1978
# 1998
# 1997
# 1970
# 1996
# 1993
# 2003
# 1984
# 1970
# 2002
# 1975
# 1989
# 1971
# 2009
# 1997
# 2003
# 2013
# 2002
# 2000
# 1998
# 2002
# 1989
# 2006
# 1997
# 2016
# 2016
# 1984
# 1995
# 1997
# 1993
# 2011
# 1988
# 1987
# 2015
# 2016
# 2018
# 2001
# 1975
# 1982
# 2009
# 1972
# 2014
# 2013
# 1998
# 2000
# 1971
# 2009
# 1976
# 2010
# 2019
# 1985
# 2021
# 1987
# 1987
# 2017
# 2012
# 1987
# 2020
# 1975
# 1982
# 1973
# 1970
# 2007
# 1977
# 2019
# 1984
# 2015
# 1989
# 1971
# 2006
# 1997
# ...

# %%
header
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 header
#
# NameError: name 'header' is not defined

# %%
row_data[-2]
# Out:
# ['999',
#  'de5Fc71DE825bFc',
#  'Olson-Solomon',
#  'https://koch.com/',
#  'Cocos (Keeling) Islands',
#  'Virtual responsive moderator',
#  '2013',
#  'Investment Banking / Venture',
#  '3825']

# %%
#industry

# %%
for row in row_data:
    print(row[-2])
# Out:
# Online Publishing
# Import / Export
# Apparel / Fashion
# Dairy
# Management Consulting
# Mental Health Care
# Computer Hardware
# Performing Arts
# Marketing / Advertising / Sales
# Investment Banking / Venture
# Capital Markets / Hedge Fund / Private Equity
# Logistics / Procurement
# Transportation
# Law Enforcement
# Financial Services
# Public Relations / PR
# Museums / Institutions
# Architecture / Planning
# Wine / Spirits
# Think Tanks
# Newspapers / Journalism
# Aviation / Aerospace
# Sports
# Defense / Space
# Real Estate / Mortgage
# Sporting Goods
# Graphic Design / Web Design
# Broadcast Media
# Media Production
# Professional Training
# Telecommunications
# Venture Capital / VC
# Luxury Goods / Jewelry
# Arts / Crafts
# Printing
# Commercial Real Estate
# Sporting Goods
# Legal Services
# Venture Capital / VC
# Human Resources / HR
# Gambling / Casinos
# Package / Freight Delivery
# Sporting Goods
# Motion Pictures / Film
# Civic / Social Organization
# Furniture
# ...

# %%
# names of the industry deals in sports

# %%
[org[2]for org in row_data if org[-2].lower() == "sports"]
# Out:
# ['Young, Buchanan and Vazquez',
#  'Adkins-Walters',
#  'Hanna PLC',
#  'Mccall-Flowers',
#  'Shields LLC',
#  'Harmon-Arellano']

# %%
#dictionary

# %%
name = [{org[2]:org[3]} for org in row_data if org[-2].lower() == "sports"] 
name
# Out:
# [{'Young, Buchanan and Vazquez': 'http://www.gregory-chapman.com/'},
#  {'Adkins-Walters': 'https://www.hernandez-allison.net/'},
#  {'Hanna PLC': 'https://www.navarro.com/'},
#  {'Mccall-Flowers': 'http://www.mathis-rowland.net/'},
#  {'Shields LLC': 'https://www.villarreal.info/'},
#  {'Harmon-Arellano': 'http://www.simmons.net/'}]

# %%
name = [org[2] for org in row_data if org[-2].lower() =="sports"]
name
# Out:
# ['Young, Buchanan and Vazquez',
#  'Adkins-Walters',
#  'Hanna PLC',
#  'Mccall-Flowers',
#  'Shields LLC',
#  'Harmon-Arellano']

# %%
name = {org[2]:org[3] for org in row_data if org[-2].lower() == "sports"}
name
# Out:
# {'Young, Buchanan and Vazquez': 'http://www.gregory-chapman.com/',
#  'Adkins-Walters': 'https://www.hernandez-allison.net/',
#  'Hanna PLC': 'https://www.navarro.com/',
#  'Mccall-Flowers': 'http://www.mathis-rowland.net/',
#  'Shields LLC': 'https://www.villarreal.info/',
#  'Harmon-Arellano': 'http://www.simmons.net/'}

# %%
len(name)
# Out:
# 6

# %%
category = [org[-2] for org in row_data]
category = set(category)
category
# Out:
# {'Accounting',
#  'Airlines / Aviation',
#  'Alternative Dispute Resolution',
#  'Alternative Medicine',
#  'Animation',
#  'Apparel / Fashion',
#  'Architecture / Planning',
#  'Arts / Crafts',
#  'Automotive',
#  'Aviation / Aerospace',
#  'Banking / Mortgage',
#  'Biotechnology / Greentech',
#  'Broadcast Media',
#  'Building Materials',
#  'Business Supplies / Equipment',
#  'Capital Markets / Hedge Fund / Private Equity',
#  'Chemicals',
#  'Civic / Social Organization',
#  'Civil Engineering',
#  'Commercial Real Estate',
#  'Computer / Network Security',
#  'Computer Games',
#  'Computer Hardware',
#  'Computer Networking',
#  'Computer Software / Engineering',
#  'Construction',
#  'Consumer Electronics',
#  'Consumer Goods',
#  'Consumer Services',
#  'Cosmetics',
#  'Dairy',
#  'Defense / Space',
#  'Design',
#  'E - Learning',
#  'Education Management',
#  'Electrical / Electronic Manufacturing',
#  'Entertainment / Movie Production',
#  'Environmental Services',
# ...

# %%
category = [org[-2] for org in row_data]
len(set(category))
# Out:
# 147

# %%
category = [org[-2] for org in row_data]
category = list(set(category))
category
# Out:
# ['Consumer Goods',
#  'Construction',
#  'Building Materials',
#  'Biotechnology / Greentech',
#  'Farming',
#  'Apparel / Fashion',
#  'Performing Arts',
#  'Shipbuilding',
#  'Internet',
#  'International Affairs',
#  'Fine Art',
#  'Machinery',
#  'Higher Education / Acadamia',
#  'Transportation',
#  'Printing',
#  'Recreational Facilities / Services',
#  'Alternative Medicine',
#  'Telecommunications',
#  'Computer Games',
#  'Furniture',
#  'Outsourcing / Offshoring',
#  'Education Management',
#  'Packaging / Containers',
#  'E - Learning',
#  'Ranching',
#  'Professional Training',
#  'Glass / Ceramics / Concrete',
#  'Chemicals',
#  'Legislative Office',
#  'Restaurants',
#  'Photography',
#  'Electrical / Electronic Manufacturing',
#  'Broadcast Media',
#  'Security / Investigations',
#  'Motion Pictures / Film',
#  'International Trade / Development',
#  'Wholesale',
#  'Sports',
#  'Political Organization',
#  'Marketing / Advertising / Sales',
#  'Accounting',
# ...

# %%
category = {}
for org in row_data:
    if org[-2].upper() not in category:         
        category[org[-2].upper()] = len([{org[2]:org[ for org in row_data if org[-2].lower() == "sports"] 
name )
# Out:
#   Cell In[18], line 4
#     category[org[-2].upper()] = len([{org[2]:org for org in row_data if org[-2].lower() == "sports"]
#                                                                                                    ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '{'

# %%
category
# Out:
# ['Consumer Goods',
#  'Construction',
#  'Building Materials',
#  'Biotechnology / Greentech',
#  'Farming',
#  'Apparel / Fashion',
#  'Performing Arts',
#  'Shipbuilding',
#  'Internet',
#  'International Affairs',
#  'Fine Art',
#  'Machinery',
#  'Higher Education / Acadamia',
#  'Transportation',
#  'Printing',
#  'Recreational Facilities / Services',
#  'Alternative Medicine',
#  'Telecommunications',
#  'Computer Games',
#  'Furniture',
#  'Outsourcing / Offshoring',
#  'Education Management',
#  'Packaging / Containers',
#  'E - Learning',
#  'Ranching',
#  'Professional Training',
#  'Glass / Ceramics / Concrete',
#  'Chemicals',
#  'Legislative Office',
#  'Restaurants',
#  'Photography',
#  'Electrical / Electronic Manufacturing',
#  'Broadcast Media',
#  'Security / Investigations',
#  'Motion Pictures / Film',
#  'International Trade / Development',
#  'Wholesale',
#  'Sports',
#  'Political Organization',
#  'Marketing / Advertising / Sales',
#  'Accounting',
# ...

# %%
dict_cat = {}
for cat in category:
    for row in row_data:
        dict_cat[cat]= len([org[2] for org in row_data if org[-2].lower() == cat])
name
# Out:
# {'Young, Buchanan and Vazquez': 'http://www.gregory-chapman.com/',
#  'Adkins-Walters': 'https://www.hernandez-allison.net/',
#  'Hanna PLC': 'https://www.navarro.com/',
#  'Mccall-Flowers': 'http://www.mathis-rowland.net/',
#  'Shields LLC': 'https://www.villarreal.info/',
#  'Harmon-Arellano': 'http://www.simmons.net/'}

# %%
dict_cat

# %%
d_emp = {}
for row in row_data:
    year = int(org[6])//100
    if year not in d_emp:
        d_emp[year] = []
    else:
        d_emp[year].append(int(org[-1]))

# %%
1989
1989//10
# Out:
# 198

# %%
d_emp
# Out:
# {19: [6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
#   6852,
# ...

# %%
# number of employee working industry wise

# %%
total = {}
for row in row_data:
    industry = row[-2]
    employees = row[-1]
    if industry not in total:
        total[industry]= employees
    else :
        total[industry] += employees

# %%
header
# Out:
# ['Index',
#  'Organization Id',
#  'Name',
#  'Website',
#  'Country',
#  'Description',
#  'Founded',
#  'Industry',
#  'Number of employees']

# %%
total
# Out:
# {'Online Publishing': '68526016934101885754238',
#  'Import / Export': '7994678988384813328955332190',
#  'Apparel / Fashion': '510568195680683928545565838326338756',
#  'Dairy': '90692781415632098217285643373744856032507383',
#  'Management Consulting': '6991498919823113',
#  'Mental Health Care': '3503249538869013404653795175835793641115662',
#  'Computer Hardware': '276292123113894633057033512',
#  'Performing Arts': '70209329141687883884261620372168',
#  'Marketing / Advertising / Sales': '270935113811883081846176',
#  'Investment Banking / Venture': '57312330122856130266353410948643825',
#  'Capital Markets / Hedge Fund / Private Equity': '22527978914666817913',
#  'Logistics / Procurement': '61651623518457865763114551961424',
#  'Transportation': '7309151761011856307617718889049661',
#  'Law Enforcement': '989031239723',
#  'Financial Services': '849775979917671550529133382729889863866',
#  'Public Relations / PR': '52052674653286749178',
# ...

# %%
#  find number of employees countrywise

# %%
cont = {}
for row in row_data :
    country = row[4].upper()
    employee = int(row[-1])
    if country not in cont :
        cont[country] = employee
    else:
        cont[country] +=employee

# %%
cont
# Out:
# {'WESTERN SAHARA': 44999,
#  'ALGERIA': 29916,
#  "COTE D'IVOIRE": 14139,
#  'UNITED STATES OF AMERICA': 48093,
#  'DENMARK': 36282,
#  'NORFOLK ISLAND': 12249,
#  'UZBEKISTAN': 21751,
#  'ISRAEL': 34102,
#  'SYRIAN ARAB REPUBLIC': 16134,
#  'ANGOLA': 11557,
#  'IRAN': 23577,
#  'AFGHANISTAN': 11244,
#  'BULGARIA': 21041,
#  'FRENCH SOUTHERN TERRITORIES': 48820,
#  'TIMOR-LESTE': 20385,
#  'SERBIA': 17563,
#  'HUNGARY': 36216,
#  'CANADA': 8075,
#  'YEMEN': 36231,
#  'JAMAICA': 11646,
#  'MARSHALL ISLANDS': 21565,
#  'GREENLAND': 18752,
#  'IRAQ': 12109,
#  'BHUTAN': 13703,
#  'THAILAND': 26639,
#  'GUADELOUPE': 26595,
#  'MALDIVES': 31850,
#  'SEYCHELLES': 19040,
#  'MYANMAR': 19369,
#  'ANTARCTICA (THE TERRITORY SOUTH OF 60 DEG S)': 21289,
#  'LIECHTENSTEIN': 15195,
#  'FALKLAND ISLANDS (MALVINAS)': 15223,
#  'JERSEY': 16819,
#  'PALESTINIAN TERRITORY': 10004,
#  'BOTSWANA': 48821,
#  'CHRISTMAS ISLAND': 37282,
#  'CHAD': 32271,
#  'PUERTO RICO': 23665,
#  'SURINAME': 44985,
# ...

# %%
cont["ZIMBABWE"]
# Out:
# 22396

# %%
max_emp= cont["ZIMBABWE"]
for row in cont:
    if cont[row]>max_emp:
        max_emp = cont[row]
print(max_emp)
# Out:
# 56655

# %%
[val for val in cont if cont[val] == max_emp]
# Out:
# ['NICARAGUA']
